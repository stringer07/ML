# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=4)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_cartpole")

del model # remove to demonstrate saving and loading

model = PPO.load("ppo_cartpole")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 21.6     |
# | time/              |          |
# |    fps             | 9360     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22340\4246536878.py in <module>
#       8
#       9 model = PPO("MlpPolicy", vec_env, verbose=1)
# ---> 10 model.learn(total_timesteps=25000)
#      11 model.save("ppo_cartpole")
#      12
#
# d:\Anaconda\anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     313         progress_bar: bool = False,
#     314     ) -> SelfPPO:
# --> 315         return super().learn(
#     316             total_timesteps=total_timesteps,
#     317             callback=callback,
#
# d:\Anaconda\anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297                 self.logger.dump(step=self.num_timesteps)
#     298
# --> 299             self.train()
#     300
#     301         callback.on_training_end()
#
# d:\Anaconda\anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py in train(self)
#     280                 # Clip grad norm
#     281                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 282                 self.policy.optimizer.step()
#     283
#     284             self._n_updates += 1
#
# d:\Anaconda\anaconda\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#     371                             )
#     372
# --> 373                 out = func(*args, **kwargs)
#     374                 self._optimizer_step_code()
#     375
#
# d:\Anaconda\anaconda\lib\site-packages\torch\optim\optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# d:\Anaconda\anaconda\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     161                 state_steps)
#     162
# --> 163             adam(
#     164                 params_with_grad,
#     165                 grads,
#
# d:\Anaconda\anaconda\lib\site-packages\torch\optim\adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     309         func = _single_tensor_adam
#     310
# --> 311     func(params,
#     312          grads,
#     313          exp_avgs,
#
# d:\Anaconda\anaconda\lib\site-packages\torch\optim\adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     430                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     431             else:
# --> 432                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     433
#     434             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading

# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5192     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 335      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.4     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6292     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 683      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.8     |
# |    ep_rew_mean      | -215     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6509     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 6858     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4160     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4409     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4597     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4780     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4962     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5118     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5362     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5476     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5501     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5542     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5655     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5750     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5801     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5887     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5943     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6014     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6053     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6105     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6144     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6191     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6224     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6261     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 6291     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6330     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 6444     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6464     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6497     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6498     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6530     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 6566     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6589     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6611     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 6623     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 6638     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 6618     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 6638     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 6644     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 6659     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 6661     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.161    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 6686     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 6712     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 6723     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.106    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 6744     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.0868   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 6758     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.0681   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 6785     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.0522   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 6793     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 6792     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 6772     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 6762     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 21174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 6762     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 21565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 6776     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 21947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 6766     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 22340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 6780     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 22683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6790     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6804     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 6807     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 6819     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 6815     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 6829     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 6835     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 25325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 6854     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 25699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 6876     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 26495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 6872     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 6880     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 6879     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 27826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 6892     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 28155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 6896     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 28560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96